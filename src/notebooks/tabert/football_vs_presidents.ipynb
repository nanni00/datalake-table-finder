# %%
import numpy as np
import pandas as pd
import torch

from table_bert import TableBertModel
from table_bert import Table, Column
# Out:
# WARNING:root:You are using the old version of `pytorch_pretrained_bert`

# %%
model = TableBertModel.from_pretrained(
    '/home/giovanni/unimore/TESI/TaBERT/pre-trained-models/tabert_base_k3/model.bin',
)

# %%
stadium_df = pd.read_csv('~/unimore/TESI/src/data/uk_football/List_of_football_stadiums_in_England_1.csv').drop('Image', axis=1)
presidents_df = pd.read_csv('~/unimore/TESI/src/data/us_presidents/List_of_presidents_of_the_United_States_1.csv').drop(['Portrait', 'Party'], axis=1)

# %%
stadium_df.head()
# Out:
#    Rank\n(England only)                    Stadium  \
# 0                   1.0            Wembley Stadium
# 1                   2.0               Old Trafford
# 2                   3.0  Tottenham Hotspur Stadium
# 3                   4.0             London Stadium
# 4                   5.0                    Anfield
#
#                         Town / City Capacity  \
# 0                   Wembley, London   90,000
# 1  Old Trafford, Greater Manchester   74,031
# 2                 Tottenham, London   62,850
# 3                 Stratford, London   62,500
# 4                Anfield, Liverpool   61,276
#
#                                  Team          League
# 0  England (Men's, women's and youth)             NaN
# 1                   Manchester United  Premier League
# 2                   Tottenham Hotspur  Premier League
# 3                     West Ham United  Premier League
# 4                           Liverpool  Premier League

# %%
presidents_df.head()
# Out:
#    No.             Name\n(Birth–Death)                              Term  \
# 0    1  George Washington\n(1732–1799)  April 30, 1789\n–\nMarch 4, 1797
# 1    2         John Adams\n(1735–1826)   March 4, 1797\n–\nMarch 4, 1801
# 2    3   Thomas Jefferson\n(1743–1826)   March 4, 1801\n–\nMarch 4, 1809
# 3    4      James Madison\n(1751–1836)   March 4, 1809\n–\nMarch 4, 1817
# 4    5       James Monroe\n(1758–1831)   March 4, 1817\n–\nMarch 4, 1825
#
#                    Party.1           Election  \
# 0             Unaffiliated  1788–1789\n\n1792
# 1               Federalist               1796
# 2  Democratic-\nRepublican     1800\n\n\n1804
# 3  Democratic-\nRepublican       1808\n\n1812
# 4  Democratic-\nRepublican       1816\n\n1820
#
#                                       Vice President
# 0                                         John Adams
# 1                                   Thomas Jefferson
# 2                       Aaron Burr\n\nGeorge Clinton
# 3  George Clinton\n\nVacant after\nApril 20, 1812...
# 4                                 Daniel D. Tompkins

# %% [markdown]
# ## First Comparison with TaBERT: stadium vs clubs_1

# %% [markdown]
# I expect to find a very high similarity between some columns of the two tables, since they have identical/similar column names/values.

# %%
# no casting at all: all the columns are interpreted as 'text' columns
stadium_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank
# (England only)  143 non-null    float64
#  1   Stadium              147 non-null    object
#  2   Town / City          147 non-null    object
#  3   Capacity             147 non-null    object
#  4   Team                 147 non-null    object
#  5   League               146 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 7.0+ KB

# %%
presidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   No.                 46 non-null     int64
#  1   Name
# (Birth–Death)  46 non-null     object
#  2   Term                46 non-null     object
#  3   Party.1             46 non-null     object
#  4   Election            46 non-null     object
#  5   Vice President      46 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.3+ KB

# %%
def get_col_type(df: pd.DataFrame, c: str):
    dtype = df.dtypes[c]
    if 'int' in str(dtype).lower() or 'float' in str(dtype).lower(): return 'real'
    else: return 'text'

# %%
def apply_tabert(ids, dataframes, contexts, onlytext=True):
    con_col_info = []
    for (id, df, context) in zip(ids, dataframes, contexts):
        if onlytext:
            header = [Column(c, 'text', sample_value=df[c].sample()) for c in df.columns]
        else:
            header = [Column(c, get_col_type(df, c), sample_value=df[c].sample()) for c in df.columns]

        data = [df[c].to_list() for c in df.columns]

        table = Table(
            id=id,
            header=header,
            data=data
        ).tokenize(model.tokenizer)

        context_encoding, column_encoding, info_dict = model.encode(
            contexts=[model.tokenizer.tokenize(context)],
            tables=[table]
        )
        con_col_info.append([context_encoding, column_encoding, info_dict])
    return con_col_info

# %%
con_col_info = apply_tabert(
    ids=[
        'A list of UK football stadiums',
        'A table with data about US presidents'
    ],
    dataframes=[
        stadium_df,
        presidents_df
    ],
    contexts=[
        '',
        ''
    ]
)

# %%
len(con_col_info), len(con_col_info[0]), len(con_col_info[1])
# Out:
# (2, 3, 3)

# %%
col_emb_stadium = con_col_info[0][1]
col_emb_presidents = con_col_info[1][1]
stadium_df.shape, tuple(col_emb_stadium.shape), '---', presidents_df.shape, tuple(col_emb_presidents.shape)
# Out:
# ((147, 6), (1, 6, 768), '---', (46, 6), (1, 6, 768))

# %%
cos = torch.nn.CosineSimilarity(dim=0)

comparisons = pd.DataFrame(columns=['stadium', 'presidents', 'cosine similarity', 'np cosim', 'dot product'])

# %%
for i, col_gdp in enumerate(stadium_df.columns):
    for j, col_pop in enumerate(presidents_df.columns):
        cosim = cos(col_emb_stadium[0, i, :], col_emb_presidents[0, j, :])
        es, ep = col_emb_stadium[0, i, :].cpu().detach().numpy(),col_emb_presidents[0, j, :].cpu().detach().numpy()
        npcosim = np.dot(es, ep) / (np.linalg.norm(es) * np.linalg.norm(ep))
        dotp = torch.dot(col_emb_stadium[0, i, :], col_emb_presidents[0, j, :])
        comparisons.loc[len(comparisons)] = [col_gdp, col_pop, float(cosim), float(npcosim), float(dotp)]

# %%
comparisons
# Out:
#                  stadium           presidents  cosine similarity  np cosim  \
# 0   Rank\n(England only)                  No.           0.888168  0.888168
# 1   Rank\n(England only)  Name\n(Birth–Death)           0.895579  0.895579
# 2   Rank\n(England only)                 Term           0.870690  0.870690
# 3   Rank\n(England only)              Party.1           0.874172  0.874172
# 4   Rank\n(England only)             Election           0.875474  0.875474
# 5   Rank\n(England only)       Vice President           0.881080  0.881080
# 6                Stadium                  No.           0.885399  0.885399
# 7                Stadium  Name\n(Birth–Death)           0.886511  0.886511
# 8                Stadium                 Term           0.887904  0.887904
# 9                Stadium              Party.1           0.877186  0.877186
# 10               Stadium             Election           0.888986  0.888986
# 11               Stadium       Vice President           0.884917  0.884917
# 12           Town / City                  No.           0.878815  0.878814
# 13           Town / City  Name\n(Birth–Death)           0.899839  0.899839
# 14           Town / City                 Term           0.886619  0.886619
# 15           Town / City              Party.1           0.881615  0.881615
# 16           Town / City             Election           0.887073  0.887073
# 17           Town / City       Vice President           0.887738  0.887738
# 18              Capacity                  No.           0.874069  0.874069
# 19              Capacity  Name\n(Birth–Death)           0.875880  0.875880
# 20              Capacity                 Term           0.886436  0.886436
# 21              Capacity              Party.1           0.876720  0.876720
# 22              Capacity             Election           0.896770  0.896770
# 23              Capacity       Vice President           0.888235  0.888235
# 24                  Team                  No.           0.894344  0.894344
# 25                  Team  Name\n(Birth–Death)           0.899862  0.899862
# 26                  Team                 Term           0.898124  0.898124
# 27                  Team              Party.1           0.903901  0.903901
# 28                  Team             Election           0.913547  0.913547
# 29                  Team       Vice President           0.914644  0.914645
# 30                League                  No.           0.886518  0.886518
# 31                League  Name\n(Birth–Death)           0.892380  0.892381
# 32                League                 Term           0.892961  0.892961
# 33                League              Party.1           0.891364  0.891364
# 34                League             Election           0.911588  0.911588
# 35                League       Vice President           0.914216  0.914216
#
#     dot product
# 0      0.720056
# 1      0.930715
# 2      0.179924
# 3      0.307881
# 4      0.336428
# 5      0.387447
# 6      0.236481
# 7      0.259515
# 8      0.289589
# 9      0.000000
# 10     0.335554
# 11     0.101944
# 12     0.187092
# 13     0.796691
# 14     0.396656
# 15     0.273758
# 16     0.424342
# 17     0.328478
# 18     0.119060
# 19     0.163065
# 20     0.463997
# 21     0.201537
# 22     0.783565
# 23     0.415651
# 24     0.444777
# 25     0.596413
# 26     0.534832
# 27     0.728415
# 28     1.000000
# 29     0.914036
# 30     0.247779
# 31     0.409778
# 32     0.416009
# 33     0.393795
# 34     0.975443
# 35     0.934197
