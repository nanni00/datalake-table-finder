# %%
import numpy as np
import pandas as pd
import torch

from table_bert import TableBertModel
from table_bert import Table, Column

# %%
model = TableBertModel.from_pretrained(
    '/home/giovanni/unimore/TESI/TaBERT/pre-trained-models/tabert_base_k3/model.bin',
)

# %% [markdown]
# ### Comparisons without any kind of casting

# %%
nations_gdp = pd.read_csv('nations_by_gdp.csv').replace('', pd.NA)
nations_pop = pd.read_csv('nations_by_population.csv').drop('Unnamed: 6', axis=1)

# %%
nations_gdp.shape, nations_pop.shape
# Out:
# ((230, 8), (241, 6))

# %%
nations_gdp.columns, nations_pop.columns
# Out:
# (Index(['Country/Territory', 'UN Region', 'IMF-Estimate', 'IMF-Year',
#         'World Bank-Estimate', 'World Bank-Year', 'CIA-Estimate', 'CIA-Year'],
#        dtype='object'),
#  Index(['Rank', 'Location', 'Population', '% of world', 'Date',
#         'Source (official or from the United Nations)'],
#        dtype='object'))

# %%
# Sampling a random fraction of both datasets to reduce total overlapping
sample_fraction = 0.5
nations_gdp = nations_gdp.sample(frac=sample_fraction)
nations_pop = nations_pop.sample(frac=sample_fraction)

# %%
nations_gdp.shape, nations_pop.shape
# Out:
# ((115, 8), (120, 6))

# %%
nations_gdp.head()
# Out:
#           Country/Territory UN Region IMF-Estimate  IMF-Year  \
# 76   British Virgin Islands  Americas          NaN       NaN
# 123            Cook Islands   Oceania          NaN       NaN
# 88                Argentina  Americas       26,506    2023.0
# 17                   Brunei      Asia       72,610    2023.0
# 74                     Guam   Oceania          NaN       NaN
#
#     World Bank-Estimate  World Bank-Year CIA-Estimate  CIA-Year
# 76                  NaN              NaN       34,200      2017
# 123                 NaN              NaN       16,700      2016
# 88               26,505           2022.0       21,500      2021
# 17               69,275           2022.0       60,100      2021
# 74                  NaN              NaN       35,600      2016

# %%
nations_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 76 to 51
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country/Territory    115 non-null    object
#  1   UN Region            115 non-null    object
#  2   IMF-Estimate         96 non-null     object
#  3   IMF-Year             96 non-null     float64
#  4   World Bank-Estimate  97 non-null     object
#  5   World Bank-Year      97 non-null     float64
#  6   CIA-Estimate         115 non-null    object
#  7   CIA-Year             115 non-null    int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 8.1+ KB

# %%
# no fine-casting, all columns interpreted as 'text'
header = [Column(c, 'text', sample_value=nations_gdp[c].sample()) for c in nations_gdp.columns]
data = [nations_gdp[c].to_list() for c in nations_gdp.columns]

table_gdp = Table(
    id='List of countries by GDP (PPP)',
    header=header,
    data=data
).tokenize(model.tokenizer)

context_gdp = 'show me countries ranked by GDP'

context_encoding_gdp, column_encoding_gdp, info_dict_gdp = model.encode(
    contexts=[model.tokenizer.tokenize(context_gdp)],
    tables=[table_gdp]
)

# %%
# no fine-casting, all columns interpreted as 'text'
header = [Column(c, 'text', sample_value=nations_pop[c].sample()) for c in nations_pop.columns]
data = [nations_pop[c].to_list() for c in nations_pop.columns]

table_pop = Table(
    id='A table of nations with their population',
    header=header,
    data=data
).tokenize(model.tokenizer)

context_pop = 'list nations by populations'

context_encoding_pop, column_encoding_pop, info_dict_pop = model.encode(
    contexts=[model.tokenizer.tokenize(context_pop)],
    tables=[table_pop]
)

# %%
column_encoding_gdp.shape, column_encoding_pop.shape
# Out:
# (torch.Size([1, 8, 768]), torch.Size([1, 6, 768]))

# %%
cos = torch.nn.CosineSimilarity(dim=0)

comparisons = pd.DataFrame(columns=['gdp_column', 'pop_column', 'cosine similarity', 'dot product'])

for i, col_gdp in enumerate(nations_gdp.columns):
    for j, col_pop in enumerate(nations_pop.columns):
        cosim = cos(column_encoding_gdp[0, i, :], column_encoding_pop[0, j, :])
        dotp = torch.dot(column_encoding_gdp[0, i, :], column_encoding_pop[0, j, :])
        comparisons.loc[len(comparisons)] = [col_gdp, col_pop, float(cosim), float(dotp)]

# %%
# Min-max normalization of the dot product column
v = comparisons['dot product']
comparisons['dot product'] = (v - v.min()) / (v.max() - v.min())

# %%
comparisons.head(10)
# Out:
#           gdp_column                                    pop_column  \
# 0  Country/Territory                                          Rank
# 1  Country/Territory                                      Location
# 2  Country/Territory                                    Population
# 3  Country/Territory                                    % of world
# 4  Country/Territory                                          Date
# 5  Country/Territory  Source (official or from the United Nations)
# 6          UN Region                                          Rank
# 7          UN Region                                      Location
# 8          UN Region                                    Population
# 9          UN Region                                    % of world
#
#    cosine similarity  dot product
# 0           0.884778     0.994602
# 1           0.883643     0.894844
# 2           0.866136     0.596209
# 3           0.855419     0.664767
# 4           0.847186     0.172924
# 5           0.861600     0.485269
# 6           0.866040     0.685567
# 7           0.871820     0.733879
# 8           0.862776     0.613356
# 9           0.838518     0.387518

# %% [markdown]
# Cosine similarity is almost always >= 0.8, even for those pairs with nothing in common (such as 'Country/Territory' and 'Rank'), and isn't very high for those expected true similar couples (like 'Country/Territory' and 'Location')
#
# Dot product shows more realistic values.
#
# However, some errors still occur: why 'Country/Territory' and 'Rank' have a really high similarity with both measures?

# %% [markdown]
# ### Specifying a better data type and dropping NA

# %%
nations_gdp = pd.read_csv('nations_by_gdp.csv').replace('', pd.NA).dropna().sample(frac=sample_fraction)
nations_pop = pd.read_csv('nations_by_population.csv').drop('Unnamed: 6', axis=1).dropna().sample(frac=sample_fraction)

# %%
nations_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 184 to 12
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country/Territory    97 non-null     object
#  1   UN Region            97 non-null     object
#  2   IMF-Estimate         97 non-null     object
#  3   IMF-Year             97 non-null     float64
#  4   World Bank-Estimate  97 non-null     object
#  5   World Bank-Year      97 non-null     float64
#  6   CIA-Estimate         97 non-null     object
#  7   CIA-Year             97 non-null     int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 6.8+ KB

# %%
nations_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 70 to 28
# Data columns (total 6 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Rank                                          120 non-null    object
#  1   Location                                      120 non-null    object
#  2   Population                                    120 non-null    object
#  3   % of world                                    120 non-null    object
#  4   Date                                          120 non-null    object
#  5   Source (official or from the United Nations)  120 non-null    object
# dtypes: object(6)
# memory usage: 6.6+ KB

# %%
for c in ['IMF-Estimate', 'World Bank-Estimate', 'CIA-Estimate']:
    nations_gdp[c] = nations_gdp[c].apply(lambda e: float(str(e).replace(',', '.')))
nations_gdp = nations_gdp.convert_dtypes()

# %%
nations_gdp.head()
# Out:
#      Country/Territory UN Region  IMF-Estimate  IMF-Year  World Bank-Estimate  \
# 184            Myanmar      Asia         5.124      2023                4.870
# 43         New Zealand   Oceania        53.809      2023               51.967
# 170              Ghana    Africa         6.905      2023                6.498
# 223             Malawi    Africa         1.668      2023                1.732
# 117  Equatorial Guinea    Africa        18.362      2023               17.396
#
#      World Bank-Year  CIA-Estimate  CIA-Year
# 184             2022           4.4      2021
# 43              2022          42.9      2021
# 170             2022           5.4      2021
# 223             2022           1.5      2021
# 117             2022          14.6      2021

# %%
nations_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 184 to 12
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country/Territory    97 non-null     string
#  1   UN Region            97 non-null     string
#  2   IMF-Estimate         97 non-null     float64
#  3   IMF-Year             97 non-null     Int64
#  4   World Bank-Estimate  97 non-null     float64
#  5   World Bank-Year      97 non-null     Int64
#  6   CIA-Estimate         97 non-null     float64
#  7   CIA-Year             97 non-null     Int64
# dtypes: Int64(3), float64(3), string(2)
# memory usage: 7.1 KB

# %%
def get_col_type(df: pd.DataFrame, c: str):
    dtype = df.dtypes[c]
    if 'int' in str(dtype).lower(): return 'int'
    elif 'float' in str(dtype).lower(): return 'real'
    else: return 'text'

# %%
header = [Column(c, get_col_type(nations_gdp, c), sample_value=nations_gdp[c].sample()) for c in nations_gdp.columns]
data = [nations_gdp[c].to_list() for c in nations_gdp.columns]

table_gdp = Table(
    id='List of countries by GDP (PPP)',
    header=header,
    data=data
).tokenize(model.tokenizer)

context_gdp = 'show me countries ranked by GDP'

context_encoding_gdp, column_encoding_gdp, info_dict_gdp = model.encode(
    contexts=[model.tokenizer.tokenize(context_gdp)],
    tables=[table_gdp]
)

# %%
nations_pop['Population'] = nations_pop['Population'].apply(lambda x: int(x.replace(',', '')))
nations_pop['% of world'] = nations_pop['% of world'].apply(lambda x: float(x.replace('%', '')))

# %%
nations_pop.head()
# Out:
#     Rank     Location  Population  % of world         Date  \
# 70    69    Guatemala    17602431       0.200   1 Jul 2023
# 157  153   East Timor     1354662       0.020   1 Jul 2023
# 170  165     Suriname      616500       0.008   1 Jul 2021
# 100   99  Switzerland     8931306       0.100  30 Sep 2023
# 175  169       Brunei      445400       0.006   1 Jul 2022
#
#     Source (official or from the United Nations)
# 70                    National annual projection
# 157                   National annual projection
# 170                            Official estimate
# 100                  National quarterly estimate
# 175                            Official estimate

# %%
nations_pop = nations_pop.convert_dtypes()
nations_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 70 to 28
# Data columns (total 6 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Rank                                          120 non-null    string
#  1   Location                                      120 non-null    string
#  2   Population                                    120 non-null    Int64
#  3   % of world                                    120 non-null    float64
#  4   Date                                          120 non-null    string
#  5   Source (official or from the United Nations)  120 non-null    string
# dtypes: Int64(1), float64(1), string(4)
# memory usage: 6.7 KB

# %%
header = [Column(c, get_col_type(nations_pop, c), sample_value=nations_pop[c].sample()) for c in nations_pop.columns]
data = [nations_pop[c].to_list() for c in nations_pop.columns]

table_pop = Table(
    id='A table of nations with their population',
    header=header,
    data=data
).tokenize(model.tokenizer)

context_pop = 'List countries by population'

context_encoding_pop, column_encoding_pop, info_dict_pop = model.encode(
    contexts=[model.tokenizer.tokenize(context_pop)],
    tables=[table_pop]
)

# %%
comparisons_casted = pd.DataFrame(columns=['gdp_column', 'pop_column', 'cosine similarity', 'dot product'])

for i, col_gdp in enumerate(nations_gdp.columns):
    for j, col_pop in enumerate(nations_pop.columns):
        cosim = cos(column_encoding_gdp[0, i, :], column_encoding_pop[0, j, :])
        dotp = torch.dot(column_encoding_gdp[0, i, :], column_encoding_pop[0, j, :])
        comparisons_casted.loc[len(comparisons_casted)] = [col_gdp, col_pop, float(cosim), float(dotp)]

# %%
# Min-max normalization of the dot product column
v = comparisons_casted['dot product']
comparisons_casted['dot product'] = (v - v.min()) / (v.max() - v.min())

# %%
pd.merge(comparisons, comparisons_casted, how='inner', on=['gdp_column', 'pop_column'], suffixes=['', '_cast'])
# Out:
#              gdp_column                                    pop_column  \
# 0     Country/Territory                                          Rank
# 1     Country/Territory                                      Location
# 2     Country/Territory                                    Population
# 3     Country/Territory                                    % of world
# 4     Country/Territory                                          Date
# 5     Country/Territory  Source (official or from the United Nations)
# 6             UN Region                                          Rank
# 7             UN Region                                      Location
# 8             UN Region                                    Population
# 9             UN Region                                    % of world
# 10            UN Region                                          Date
# 11            UN Region  Source (official or from the United Nations)
# 12         IMF-Estimate                                          Rank
# 13         IMF-Estimate                                      Location
# 14         IMF-Estimate                                    Population
# 15         IMF-Estimate                                    % of world
# 16         IMF-Estimate                                          Date
# 17         IMF-Estimate  Source (official or from the United Nations)
# 18             IMF-Year                                          Rank
# 19             IMF-Year                                      Location
# 20             IMF-Year                                    Population
# 21             IMF-Year                                    % of world
# 22             IMF-Year                                          Date
# 23             IMF-Year  Source (official or from the United Nations)
# 24  World Bank-Estimate                                          Rank
# 25  World Bank-Estimate                                      Location
# 26  World Bank-Estimate                                    Population
# 27  World Bank-Estimate                                    % of world
# 28  World Bank-Estimate                                          Date
# 29  World Bank-Estimate  Source (official or from the United Nations)
# 30      World Bank-Year                                          Rank
# 31      World Bank-Year                                      Location
# 32      World Bank-Year                                    Population
# 33      World Bank-Year                                    % of world
# 34      World Bank-Year                                          Date
# 35      World Bank-Year  Source (official or from the United Nations)
# 36         CIA-Estimate                                          Rank
# 37         CIA-Estimate                                      Location
# 38         CIA-Estimate                                    Population
# 39         CIA-Estimate                                    % of world
# 40         CIA-Estimate                                          Date
# 41         CIA-Estimate  Source (official or from the United Nations)
# 42             CIA-Year                                          Rank
# 43             CIA-Year                                      Location
# 44             CIA-Year                                    Population
# 45             CIA-Year                                    % of world
# 46             CIA-Year                                          Date
# 47             CIA-Year  Source (official or from the United Nations)
#
#     cosine similarity  dot product  cosine similarity_cast  dot product_cast
# 0            0.884778     0.994602                0.862609          1.000000
# 1            0.883643     0.894844                0.873803          0.848555
# 2            0.866136     0.596209                0.791581          0.322378
# 3            0.855419     0.664767                0.811937          0.316809
# 4            0.847186     0.172924                0.815381          0.000000
# 5            0.861600     0.485269                0.824068          0.286756
# 6            0.866040     0.685567                0.857542          0.594559
# 7            0.871820     0.733879                0.894183          0.780465
# 8            0.862776     0.613356                0.816314          0.343423
# 9            0.838518     0.387518                0.840898          0.385883
# 10           0.834997     0.000000                0.854085          0.191619
# 11           0.847853     0.280552                0.863599          0.488881
# 12           0.869784     0.562388                0.840180          0.393558
# 13           0.868759     0.466817                0.869264          0.487218
# 14           0.872405     0.615115                0.812559          0.322614
# 15           0.864693     0.749865                0.853874          0.590924
# 16           0.866744     0.474364                0.866859          0.387857
# 17           0.875159     0.658454                0.876155          0.685650
# 18           0.863661     0.504519                0.838702          0.360129
# 19           0.860186     0.357408                0.871082          0.497163
# 20           0.865116     0.532756                0.817584          0.378148
# 21           0.862232     0.769437                0.852395          0.557227
# 22           0.872039     0.657881                0.878753          0.528384
# 23           0.872874     0.682310                0.875208          0.659187
# 24           0.859824     0.477871                0.833610          0.272573
# 25           0.862705     0.465161                0.872513          0.496016
# 26           0.869587     0.682719                0.817034          0.351023
# 27           0.870331     1.000000                0.865664          0.714784
# 28           0.863653     0.535278                0.877441          0.491564
# 29           0.877994     0.846415                0.888895          0.818971
# 30           0.855702     0.322561                0.839104          0.283534
# 31           0.857895     0.295739                0.875296          0.468782
# 32           0.865983     0.537615                0.824208          0.386470
# 33           0.870047     0.923901                0.866234          0.657890
# 34           0.871581     0.634609                0.890218          0.592733
# 35           0.881619     0.853646                0.893692          0.816600
# 36           0.872260     0.499741                0.835776          0.304494
# 37           0.877411     0.533551                0.866022          0.414532
# 38           0.882112     0.703735                0.810103          0.258874
# 39           0.875594     0.866401                0.848752          0.491660
# 40           0.886710     0.778470                0.879086          0.515899
# 41           0.893153     0.920254                0.887150          0.799167
# 42           0.885293     0.500886                0.842888          0.306457
# 43           0.889890     0.521725                0.879344          0.493375
# 44           0.894125     0.680793                0.825386          0.375046
# 45           0.882225     0.732101                0.853700          0.463476
# 46           0.901854     0.818752                0.894818          0.623812
# 47           0.904906     0.888587                0.887480          0.707104

# %% [markdown]
# Results aren't different from non-casted version. Why? Is this a problem of data itself, or embeddings, or cosine similarity distance?
